# %%
from define import getCode

# %%
from define import generateImage

# %%
code = getCode()

# %%
generateImage(code)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=223x50 at 0x7F8456EE6A50>

# %%
 10 from helper import imageToVertor
 11 from helper import codeToVertor
