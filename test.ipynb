# %%
from reader import read_code
from define import get_code
from define import generate_image

# %%
code = get_code()
image = generate_image(code)
print 'code:', code
print 'prediction:', read_code(image)
image
# Out:
# code: d3p4n
# prediction: d3p4n
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=223x50 at 0x7FF2F8CBD4D0>

# %%
import requests
from PIL import Image
from StringIO import StringIO

# %%
url = 'https://s.nacao.org.cn/servlet/ValidateCode?time='
response = requests.get(url)
image = Image.open(StringIO(response.content))
print 'prediction:', read_code(image)
image
# Out:
# prediction: b4xac
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=223x50 at 0x7FF2F8C9DB90>
