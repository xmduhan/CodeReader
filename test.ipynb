# %%
from reader import read_code
from define import get_code
from define import generate_image
# Out:
# INFO:tensorflow:Restoring parameters from model/0/model
# INFO:tensorflow:Restoring parameters from model/1/model
# INFO:tensorflow:Restoring parameters from model/2/model
# INFO:tensorflow:Restoring parameters from model/3/model
# INFO:tensorflow:Restoring parameters from model/4/model

# %%
code = get_code()
image = generate_image(code)
print 'real:', code
print 'prediction:', read_code(image)
image
# Out:
# real: 3x8ne
# prediction: 3qwn3
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=223x50 at 0x7F6087E3AC50>
